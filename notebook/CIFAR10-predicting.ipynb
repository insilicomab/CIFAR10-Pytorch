# %% [markdown]
# # 環境確認

# %%
import sys
import torch

print("Pythonのバージョン：",sys.version)
print("PyTorchのバージョン：", torch.__version__)
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# Pythonのバージョン： 3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]
# PyTorchのバージョン： 1.10.0+cu111
# 使用しているGPUの確認
# Tue Apr  5 11:59:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # データのダウンロード

# %%
# !pip install signate

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth


auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'signate.json'", fields="files(id)").execute()
signate_api_key = results.get('files', [])

filename = "/root/.signate/signate.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=signate_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Collecting signate
#   Downloading signate-0.9.9-py3-none-any.whl (37 kB)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting six>=1.16
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from signate) (2021.10.8)
# Collecting urllib3>=1.26.7
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 15.5 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from signate) (0.8.9)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from signate) (7.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from signate) (2.8.2)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=988c186824d1f349a95b9c57e166d600bfe52ea21f7cac90c0ec2eb4dccbef40
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: six, wget, urllib3, signate
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed signate-0.9.9 six-1.16.0 urllib3-1.26.9 wget-3.2
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Download 100%.

# %%
# !signate list
# !signate files --competition-id=133
# !signate download --competition-id=133
# Out:
#   competitionId  title                                                                             closing     prize        submitters
# ---------------  --------------------------------------------------------------------------------  ----------  ---------  ------------
#               1  【練習問題】銀行の顧客ターゲティング                                              -                              5566
#              24  【練習問題】お弁当の需要予測                                                      -                              6905
#              27  【練習問題】Jリーグの観客動員数予測                                               -                              1689
#             100  【練習問題】手書き文字認識                                                        -           Knowledge           219
#             102  【練習問題】タイタニックの生存予測                                                -           Knowledge          1415
#             103  【練習問題】音楽ラベリング                                                        -           Knowledge            65
#             104  【練習問題】スパムメール分類                                                      -           Knowledge           148
#             105  【練習問題】毒キノコの分類                                                        -           Knowledge           280
#             106  【練習問題】アワビの年齢予測                                                      -           Knowledge           377
#             107  【練習問題】国勢調査からの収入予測                                                -           Knowledge           572
#             108  【練習問題】画像ラベリング（20種類）                                              -           Knowledge           229
#             112  【練習問題】ワインの品種の予測                                                    -           Knowledge           323
#             113  【練習問題】山火事の消失面積予測                                                  -           Knowledge           214
#             114  【練習問題】レンタル自転車の利用者数予測                                          -           Knowledge           400
#             115  【練習問題】アヤメの分類                                                          -           Knowledge           362
#             116  【練習問題】活動センサーログからの動作予測                                        -           Knowledge            57
#             118  【練習問題】テニスの試合結果の予測                                                -           Knowledge           133
#             121  【練習問題】自動車の走行距離予測                                                  -           Knowledge          1536
#             122  【練習問題】自動車の評価                                                          -           Knowledge           327
#             123  【練習問題】オゾンレベルの分類                                                    -           Knowledge            58
#             124  【練習問題】ボットの判別                                                          -           Knowledge           315
#             125  【練習問題】ガラスの分類                                                          -           Knowledge           180
#             126  【練習問題】林型の分類                                                            -           Knowledge            45
#             127  【練習問題】ゲーム選手のリーグ分類                                                -           Knowledge            66
#             128  【練習問題】ステンレス板の欠陥分類                                                -           Knowledge            85
#             129  【練習問題】都市サイクルの燃料消費量予測                                          -           Knowledge           156
#             130  【練習問題】天秤のバランス分類                                                    -           Knowledge           133
#             132  【練習問題】ネット広告のクリック予測                                              -           Knowledge           151
#             133  【練習問題】画像ラベリング（10種類）                                              -                               357
#             135  【練習問題】ネット画像の分類                                                      -                                77
#             262  国立国会図書館の画像データレイアウト認識                                          2100-12-31  -                    96
#             263  産業技術総合研究所 衛星画像分析コンテスト                                         2100-12-31  -                    49
#             264  マイナビ × SIGNATE Student Cup 2019: 賃貸物件の家賃予測                           2100-12-31  -                   399
#             265  【練習問題】健診データによる肝疾患判定                                            -                               549
#             266  【練習問題】民泊サービスの宿泊価格予測                                            -                               602
#             267  海洋研究開発機構 熱帯低気圧（台風等）検出アルゴリズム作成                         2100-12-31  -                    23
#             268  オプト レコメンドエンジン作成                                                     2100-12-31                       43
#             269  アップル 引越し需要予測                                                           2100-12-31  -                   366
#             270  Weather Challenge：雲画像予測                                                     2100-12-31  -                     9
#             271  JR西日本 走行中の北陸新幹線車両台車部の着雪量予測                                 2100-12-31  -                    24
#             288  Sansan 名刺の項目予測                                                             2100-12-31  -                    33
#             294  【練習問題】債務不履行リスクの低減                                                -                               204
#             358  【練習問題】機械稼働音の異常検知                                                  -                                76
#             404  【練習問題】モノクロ顔画像の感情分類                                              -                                90
#             406  【練習問題】鋳造製品の欠陥検出                                                    -                               218
#             409  【練習問題】株価の推移予測                                                        -                               186
#             565  SIGNATE Student Cup 2021春：楽曲のジャンル推定チャレンジ！！                      2100-12-31  -                    70
#             567  SIGNATE Student Cup 2021秋：オペレーション最適化に向けたシェアサイクルの利用予測  2100-12-31  -                    54
#             595  医学論文の自動仕分けチャレンジ                                                    2100-12-31                       13
#   fileId  name               title                                   size  updated_at
# --------  -----------------  ----------------------------------  --------  -------------------
#      432  train_images.zip   学習用画像データ                    14268112  2018-07-07 01:42:24
#      433  test_images.zip    評価用画像データ                    22815489  2018-07-07 01:42:44
#      435  label_master.tsv   ラベルマスタ                             104  2021-01-14 11:33:12
#      434  train_master.tsv   学習用画像データとラベルIDの対応表     88910  2021-01-14 11:33:12
#      438  sample_submit.tsv  応募用サンプルファイル                134890  2021-01-14 11:33:17
# label_master.tsv
#
# train_master.tsv
#
# sample_submit.tsv
#
# train_images.zip
#
# test_images.zip
#
#
# Download completed.

# %%
# !unzip test_images.zip
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: test_images/test_3699.jpg
#   inflating: test_images/test_37.jpg
#   inflating: test_images/test_370.jpg
#   inflating: test_images/test_3700.jpg
#   inflating: test_images/test_3701.jpg
#   inflating: test_images/test_3702.jpg
#   inflating: test_images/test_3703.jpg
#   inflating: test_images/test_3704.jpg
#   inflating: test_images/test_3705.jpg
#   inflating: test_images/test_3706.jpg
#   inflating: test_images/test_3707.jpg
#   inflating: test_images/test_3708.jpg
#   inflating: test_images/test_3709.jpg
#   inflating: test_images/test_371.jpg
#   inflating: test_images/test_3710.jpg
#   inflating: test_images/test_3711.jpg
#   inflating: test_images/test_3712.jpg
#   inflating: test_images/test_3713.jpg
#   inflating: test_images/test_3714.jpg
#   inflating: test_images/test_3715.jpg
#   inflating: test_images/test_3716.jpg
#   inflating: test_images/test_3717.jpg
#   inflating: test_images/test_3718.jpg
#   inflating: test_images/test_3719.jpg
#   inflating: test_images/test_372.jpg
#   inflating: test_images/test_3720.jpg
#   inflating: test_images/test_3721.jpg
#   inflating: test_images/test_3722.jpg
#   inflating: test_images/test_3723.jpg
#   inflating: test_images/test_3724.jpg
#   inflating: test_images/test_3725.jpg
#   inflating: test_images/test_3726.jpg
#   inflating: test_images/test_3727.jpg
#   inflating: test_images/test_3728.jpg
#   inflating: test_images/test_3729.jpg
#   inflating: test_images/test_373.jpg
#   inflating: test_images/test_3730.jpg
#   inflating: test_images/test_3731.jpg
#   inflating: test_images/test_3732.jpg
#   inflating: test_images/test_3733.jpg
#   inflating: test_images/test_3734.jpg
#   inflating: test_images/test_3735.jpg
#   inflating: test_images/test_3736.jpg
#   inflating: test_images/test_3737.jpg
#   inflating: test_images/test_3738.jpg
#   inflating: test_images/test_3739.jpg
#   inflating: test_images/test_374.jpg
#   inflating: test_images/test_3740.jpg
#   inflating: test_images/test_3741.jpg
#   inflating: test_images/test_3742.jpg
#   inflating: test_images/test_3743.jpg
#   inflating: test_images/test_3744.jpg
#   inflating: test_images/test_3745.jpg
#   inflating: test_images/test_3746.jpg
#   inflating: test_images/test_3747.jpg
#   inflating: test_images/test_3748.jpg
#   inflating: test_images/test_3749.jpg
#   inflating: test_images/test_375.jpg
#   inflating: test_images/test_3750.jpg
#   inflating: test_images/test_3751.jpg
#   inflating: test_images/test_3752.jpg
#   inflating: test_images/test_3753.jpg
#   inflating: test_images/test_3754.jpg
#   inflating: test_images/test_3755.jpg
#   inflating: test_images/test_3756.jpg
#   inflating: test_images/test_3757.jpg
#   inflating: test_images/test_3758.jpg
#   inflating: test_images/test_3759.jpg
#   inflating: test_images/test_376.jpg
#   inflating: test_images/test_3760.jpg
#   inflating: test_images/test_3761.jpg
#   inflating: test_images/test_3762.jpg
#   inflating: test_images/test_3763.jpg
#   inflating: test_images/test_3764.jpg
#   inflating: test_images/test_3765.jpg
#   inflating: test_images/test_3766.jpg
#   inflating: test_images/test_3767.jpg
#   inflating: test_images/test_3768.jpg
#   inflating: test_images/test_3769.jpg
#   inflating: test_images/test_377.jpg
#   inflating: test_images/test_3770.jpg
#   inflating: test_images/test_3771.jpg
#   inflating: test_images/test_3772.jpg
#   inflating: test_images/test_3773.jpg
#   inflating: test_images/test_3774.jpg
#   inflating: test_images/test_3775.jpg
#   inflating: test_images/test_3776.jpg
#   inflating: test_images/test_3777.jpg
#   inflating: test_images/test_3778.jpg
#   inflating: test_images/test_3779.jpg
#   inflating: test_images/test_378.jpg
#   inflating: test_images/test_3780.jpg
#   inflating: test_images/test_3781.jpg
#   inflating: test_images/test_3782.jpg
#   inflating: test_images/test_3783.jpg
#   inflating: test_images/test_3784.jpg
#   inflating: test_images/test_3785.jpg
#   inflating: test_images/test_3786.jpg
#   inflating: test_images/test_3787.jpg
#   inflating: test_images/test_3788.jpg
#   inflating: test_images/test_3789.jpg
#   inflating: test_images/test_379.jpg
#   inflating: test_images/test_3790.jpg
#   inflating: test_images/test_3791.jpg
#   inflating: test_images/test_3792.jpg
#   inflating: test_images/test_3793.jpg
#   inflating: test_images/test_3794.jpg
#   inflating: test_images/test_3795.jpg
#   inflating: test_images/test_3796.jpg
#   inflating: test_images/test_3797.jpg
#   inflating: test_images/test_3798.jpg
#   inflating: test_images/test_3799.jpg
#   inflating: test_images/test_38.jpg
#   inflating: test_images/test_380.jpg
#   inflating: test_images/test_3800.jpg
#   inflating: test_images/test_3801.jpg
#   inflating: test_images/test_3802.jpg
#   inflating: test_images/test_3803.jpg
#   inflating: test_images/test_3804.jpg
#   inflating: test_images/test_3805.jpg
#   inflating: test_images/test_3806.jpg
#   inflating: test_images/test_3807.jpg
#   inflating: test_images/test_3808.jpg
#   inflating: test_images/test_3809.jpg
#   inflating: test_images/test_381.jpg
#   inflating: test_images/test_3810.jpg
#   inflating: test_images/test_3811.jpg
#   inflating: test_images/test_3812.jpg
#   inflating: test_images/test_3813.jpg
#   inflating: test_images/test_3814.jpg
#   inflating: test_images/test_3815.jpg
#   inflating: test_images/test_3816.jpg
#   inflating: test_images/test_3817.jpg
#   inflating: test_images/test_3818.jpg
#   inflating: test_images/test_3819.jpg
#   inflating: test_images/test_382.jpg
#   inflating: test_images/test_3820.jpg
#   inflating: test_images/test_3821.jpg
#   inflating: test_images/test_3822.jpg
#   inflating: test_images/test_3823.jpg
#   inflating: test_images/test_3824.jpg
#   inflating: test_images/test_3825.jpg
#   inflating: test_images/test_3826.jpg
#   inflating: test_images/test_3827.jpg
#   inflating: test_images/test_3828.jpg
#   inflating: test_images/test_3829.jpg
#   inflating: test_images/test_383.jpg
#   inflating: test_images/test_3830.jpg
#   inflating: test_images/test_3831.jpg
#   inflating: test_images/test_3832.jpg
#   inflating: test_images/test_3833.jpg
#   inflating: test_images/test_3834.jpg
#   inflating: test_images/test_3835.jpg
#   inflating: test_images/test_3836.jpg
#   inflating: test_images/test_3837.jpg
#   inflating: test_images/test_3838.jpg
#   inflating: test_images/test_3839.jpg
#   inflating: test_images/test_384.jpg
#   inflating: test_images/test_3840.jpg
#   inflating: test_images/test_3841.jpg
#   inflating: test_images/test_3842.jpg
#   inflating: test_images/test_3843.jpg
#   inflating: test_images/test_3844.jpg
#   inflating: test_images/test_3845.jpg
#   inflating: test_images/test_3846.jpg
#   inflating: test_images/test_3847.jpg
#   inflating: test_images/test_3848.jpg
#   inflating: test_images/test_3849.jpg
#   inflating: test_images/test_385.jpg
#   inflating: test_images/test_3850.jpg
#   inflating: test_images/test_3851.jpg
#   inflating: test_images/test_3852.jpg
#   inflating: test_images/test_3853.jpg
#   inflating: test_images/test_3854.jpg
#   inflating: test_images/test_3855.jpg
#   inflating: test_images/test_3856.jpg
#   inflating: test_images/test_3857.jpg
#   inflating: test_images/test_3858.jpg
#   inflating: test_images/test_3859.jpg
#   inflating: test_images/test_386.jpg
#   inflating: test_images/test_3860.jpg
#   inflating: test_images/test_3861.jpg
#   inflating: test_images/test_3862.jpg
#   inflating: test_images/test_3863.jpg
#   inflating: test_images/test_3864.jpg
#   inflating: test_images/test_3865.jpg
#   inflating: test_images/test_3866.jpg
#   inflating: test_images/test_3867.jpg
#   inflating: test_images/test_3868.jpg
#   inflating: test_images/test_3869.jpg
#   inflating: test_images/test_387.jpg
#   inflating: test_images/test_3870.jpg
#   inflating: test_images/test_3871.jpg
#   inflating: test_images/test_3872.jpg
#   inflating: test_images/test_3873.jpg
#   inflating: test_images/test_3874.jpg
#   inflating: test_images/test_3875.jpg
#   inflating: test_images/test_3876.jpg
#   inflating: test_images/test_3877.jpg
#   inflating: test_images/test_3878.jpg
#   inflating: test_images/test_3879.jpg
#   inflating: test_images/test_388.jpg
#   inflating: test_images/test_3880.jpg
#   inflating: test_images/test_3881.jpg
#   inflating: test_images/test_3882.jpg
#   inflating: test_images/test_3883.jpg
#   inflating: test_images/test_3884.jpg
#   inflating: test_images/test_3885.jpg
#   inflating: test_images/test_3886.jpg
#   inflating: test_images/test_3887.jpg
#   inflating: test_images/test_3888.jpg
#   inflating: test_images/test_3889.jpg
#   inflating: test_images/test_389.jpg
#   inflating: test_images/test_3890.jpg
#   inflating: test_images/test_3891.jpg
#   inflating: test_images/test_3892.jpg
#   inflating: test_images/test_3893.jpg
#   inflating: test_images/test_3894.jpg
#   inflating: test_images/test_3895.jpg
#   inflating: test_images/test_3896.jpg
#   inflating: test_images/test_3897.jpg
#   inflating: test_images/test_3898.jpg
#   inflating: test_images/test_3899.jpg
#   inflating: test_images/test_39.jpg
#   inflating: test_images/test_390.jpg
#   inflating: test_images/test_3900.jpg
#   inflating: test_images/test_3901.jpg
#   inflating: test_images/test_3902.jpg
#   inflating: test_images/test_3903.jpg
#   inflating: test_images/test_3904.jpg
#   inflating: test_images/test_3905.jpg
#   inflating: test_images/test_3906.jpg
#   inflating: test_images/test_3907.jpg
#   inflating: test_images/test_3908.jpg
#   inflating: test_images/test_3909.jpg
#   inflating: test_images/test_391.jpg
#   inflating: test_images/test_3910.jpg
#   inflating: test_images/test_3911.jpg
#   inflating: test_images/test_3912.jpg
#   inflating: test_images/test_3913.jpg
#   inflating: test_images/test_3914.jpg
#   inflating: test_images/test_3915.jpg
#   inflating: test_images/test_3916.jpg
#   inflating: test_images/test_3917.jpg
#   inflating: test_images/test_3918.jpg
#   inflating: test_images/test_3919.jpg
#   inflating: test_images/test_392.jpg
#   inflating: test_images/test_3920.jpg
#   inflating: test_images/test_3921.jpg
#   inflating: test_images/test_3922.jpg
#   inflating: test_images/test_3923.jpg
#   inflating: test_images/test_3924.jpg
#   inflating: test_images/test_3925.jpg
#   inflating: test_images/test_3926.jpg
#   inflating: test_images/test_3927.jpg
#   inflating: test_images/test_3928.jpg
#   inflating: test_images/test_3929.jpg
#   inflating: test_images/test_393.jpg
#   inflating: test_images/test_3930.jpg
#   inflating: test_images/test_3931.jpg
#   inflating: test_images/test_3932.jpg
#   inflating: test_images/test_3933.jpg
#   inflating: test_images/test_3934.jpg
#   inflating: test_images/test_3935.jpg
#   inflating: test_images/test_3936.jpg
#   inflating: test_images/test_3937.jpg
#   inflating: test_images/test_3938.jpg
#   inflating: test_images/test_3939.jpg
#   inflating: test_images/test_394.jpg
#   inflating: test_images/test_3940.jpg
#   inflating: test_images/test_3941.jpg
#   inflating: test_images/test_3942.jpg
#   inflating: test_images/test_3943.jpg
#   inflating: test_images/test_3944.jpg
#   inflating: test_images/test_3945.jpg
#   inflating: test_images/test_3946.jpg
#   inflating: test_images/test_3947.jpg
#   inflating: test_images/test_3948.jpg
#   inflating: test_images/test_3949.jpg
#   inflating: test_images/test_395.jpg
#   inflating: test_images/test_3950.jpg
#   inflating: test_images/test_3951.jpg
#   inflating: test_images/test_3952.jpg
#   inflating: test_images/test_3953.jpg
#   inflating: test_images/test_3954.jpg
#   inflating: test_images/test_3955.jpg
#   inflating: test_images/test_3956.jpg
#   inflating: test_images/test_3957.jpg
#   inflating: test_images/test_3958.jpg
#   inflating: test_images/test_3959.jpg
#   inflating: test_images/test_396.jpg
#   inflating: test_images/test_3960.jpg
#   inflating: test_images/test_3961.jpg
#   inflating: test_images/test_3962.jpg
#   inflating: test_images/test_3963.jpg
#   inflating: test_images/test_3964.jpg
#   inflating: test_images/test_3965.jpg
#   inflating: test_images/test_3966.jpg
#   inflating: test_images/test_3967.jpg
#   inflating: test_images/test_3968.jpg
#   inflating: test_images/test_3969.jpg
#   inflating: test_images/test_397.jpg
#   inflating: test_images/test_3970.jpg
#   inflating: test_images/test_3971.jpg
#   inflating: test_images/test_3972.jpg
#   inflating: test_images/test_3973.jpg
#   inflating: test_images/test_3974.jpg
#   inflating: test_images/test_3975.jpg
#   inflating: test_images/test_3976.jpg
#   inflating: test_images/test_3977.jpg
#   inflating: test_images/test_3978.jpg
#   inflating: test_images/test_3979.jpg
#   inflating: test_images/test_398.jpg
#   inflating: test_images/test_3980.jpg
#   inflating: test_images/test_3981.jpg
#   inflating: test_images/test_3982.jpg
#   inflating: test_images/test_3983.jpg
#   inflating: test_images/test_3984.jpg
#   inflating: test_images/test_3985.jpg
#   inflating: test_images/test_3986.jpg
#   inflating: test_images/test_3987.jpg
#   inflating: test_images/test_3988.jpg
#   inflating: test_images/test_3989.jpg
#   inflating: test_images/test_399.jpg
#   inflating: test_images/test_3990.jpg
#   inflating: test_images/test_3991.jpg
#   inflating: test_images/test_3992.jpg
#   inflating: test_images/test_3993.jpg
#   inflating: test_images/test_3994.jpg
#   inflating: test_images/test_3995.jpg
#   inflating: test_images/test_3996.jpg
#   inflating: test_images/test_3997.jpg
#   inflating: test_images/test_3998.jpg
#   inflating: test_images/test_3999.jpg
#   inflating: test_images/test_4.jpg
#   inflating: test_images/test_40.jpg
#   inflating: test_images/test_400.jpg
#   inflating: test_images/test_4000.jpg
#   inflating: test_images/test_4001.jpg
#   inflating: test_images/test_4002.jpg
#   inflating: test_images/test_4003.jpg
#   inflating: test_images/test_4004.jpg
#   inflating: test_images/test_4005.jpg
#   inflating: test_images/test_4006.jpg
#   inflating: test_images/test_4007.jpg
#   inflating: test_images/test_4008.jpg
#   inflating: test_images/test_4009.jpg
#   inflating: test_images/test_401.jpg
#   inflating: test_images/test_4010.jpg
#   inflating: test_images/test_4011.jpg
#   inflating: test_images/test_4012.jpg
#   inflating: test_images/test_4013.jpg
#   inflating: test_images/test_4014.jpg
#   inflating: test_images/test_4015.jpg
#   inflating: test_images/test_4016.jpg
#   inflating: test_images/test_4017.jpg
#   inflating: test_images/test_4018.jpg
#   inflating: test_images/test_4019.jpg
#   inflating: test_images/test_402.jpg
#   inflating: test_images/test_4020.jpg
#   inflating: test_images/test_4021.jpg
#   inflating: test_images/test_4022.jpg
#   inflating: test_images/test_4023.jpg
#   inflating: test_images/test_4024.jpg
#   inflating: test_images/test_4025.jpg
#   inflating: test_images/test_4026.jpg
#   inflating: test_images/test_4027.jpg
#   inflating: test_images/test_4028.jpg
#   inflating: test_images/test_4029.jpg
#   inflating: test_images/test_403.jpg
#   inflating: test_images/test_4030.jpg
#   inflating: test_images/test_4031.jpg
#   inflating: test_images/test_4032.jpg
#   inflating: test_images/test_4033.jpg
#   inflating: test_images/test_4034.jpg
#   inflating: test_images/test_4035.jpg
#   inflating: test_images/test_4036.jpg
#   inflating: test_images/test_4037.jpg
#   inflating: test_images/test_4038.jpg
#   inflating: test_images/test_4039.jpg
#   inflating: test_images/test_404.jpg
#   inflating: test_images/test_4040.jpg
#   inflating: test_images/test_4041.jpg
#   inflating: test_images/test_4042.jpg
#   inflating: test_images/test_4043.jpg
#   inflating: test_images/test_4044.jpg
#   inflating: test_images/test_4045.jpg
#   inflating: test_images/test_4046.jpg
#   inflating: test_images/test_4047.jpg
#   inflating: test_images/test_4048.jpg
#   inflating: test_images/test_4049.jpg
#   inflating: test_images/test_405.jpg
#   inflating: test_images/test_4050.jpg
#   inflating: test_images/test_4051.jpg
#   inflating: test_images/test_4052.jpg
#   inflating: test_images/test_4053.jpg
#   inflating: test_images/test_4054.jpg
#   inflating: test_images/test_4055.jpg
#   inflating: test_images/test_4056.jpg
#   inflating: test_images/test_4057.jpg
#   inflating: test_images/test_4058.jpg
#   inflating: test_images/test_4059.jpg
#   inflating: test_images/test_406.jpg
#   inflating: test_images/test_4060.jpg
#   inflating: test_images/test_4061.jpg
#   inflating: test_images/test_4062.jpg
#   inflating: test_images/test_4063.jpg
#   inflating: test_images/test_4064.jpg
#   inflating: test_images/test_4065.jpg
#   inflating: test_images/test_4066.jpg
#   inflating: test_images/test_4067.jpg
#   inflating: test_images/test_4068.jpg
#   inflating: test_images/test_4069.jpg
#   inflating: test_images/test_407.jpg
#   inflating: test_images/test_4070.jpg
#   inflating: test_images/test_4071.jpg
#   inflating: test_images/test_4072.jpg
#   inflating: test_images/test_4073.jpg
#   inflating: test_images/test_4074.jpg
#   inflating: test_images/test_4075.jpg
#   inflating: test_images/test_4076.jpg
#   inflating: test_images/test_4077.jpg
#   inflating: test_images/test_4078.jpg
#   inflating: test_images/test_4079.jpg
#   inflating: test_images/test_408.jpg
#   inflating: test_images/test_4080.jpg
#   inflating: test_images/test_4081.jpg
#   inflating: test_images/test_4082.jpg
#   inflating: test_images/test_4083.jpg
#   inflating: test_images/test_4084.jpg
#   inflating: test_images/test_4085.jpg
#   inflating: test_images/test_4086.jpg
#   inflating: test_images/test_4087.jpg
#   inflating: test_images/test_4088.jpg
#   inflating: test_images/test_4089.jpg
#   inflating: test_images/test_409.jpg
#   inflating: test_images/test_4090.jpg
#   inflating: test_images/test_4091.jpg
#   inflating: test_images/test_4092.jpg
#   inflating: test_images/test_4093.jpg
#   inflating: test_images/test_4094.jpg
#   inflating: test_images/test_4095.jpg
#   inflating: test_images/test_4096.jpg
#   inflating: test_images/test_4097.jpg
#   inflating: test_images/test_4098.jpg
#   inflating: test_images/test_4099.jpg
#   inflating: test_images/test_41.jpg
#   inflating: test_images/test_410.jpg
#   inflating: test_images/test_4100.jpg
#   inflating: test_images/test_4101.jpg
#   inflating: test_images/test_4102.jpg
#   inflating: test_images/test_4103.jpg
#   inflating: test_images/test_4104.jpg
#   inflating: test_images/test_4105.jpg
#   inflating: test_images/test_4106.jpg
#   inflating: test_images/test_4107.jpg
#   inflating: test_images/test_4108.jpg
#   inflating: test_images/test_4109.jpg
#   inflating: test_images/test_411.jpg
#   inflating: test_images/test_4110.jpg
#   inflating: test_images/test_4111.jpg
#   inflating: test_images/test_4112.jpg
#   inflating: test_images/test_4113.jpg
#   inflating: test_images/test_4114.jpg
#   inflating: test_images/test_4115.jpg
#   inflating: test_images/test_4116.jpg
#   inflating: test_images/test_4117.jpg
#   inflating: test_images/test_4118.jpg
#   inflating: test_images/test_4119.jpg
#   inflating: test_images/test_412.jpg
#   inflating: test_images/test_4120.jpg
#   inflating: test_images/test_4121.jpg
#   inflating: test_images/test_4122.jpg
#   inflating: test_images/test_4123.jpg
#   inflating: test_images/test_4124.jpg
#   inflating: test_images/test_4125.jpg
#   inflating: test_images/test_4126.jpg
#   inflating: test_images/test_4127.jpg
#   inflating: test_images/test_4128.jpg
#   inflating: test_images/test_4129.jpg
#   inflating: test_images/test_413.jpg
#   inflating: test_images/test_4130.jpg
#   inflating: test_images/test_4131.jpg
#   inflating: test_images/test_4132.jpg
#   inflating: test_images/test_4133.jpg
#   inflating: test_images/test_4134.jpg
#   inflating: test_images/test_4135.jpg
#   inflating: test_images/test_4136.jpg
#   inflating: test_images/test_4137.jpg
#   inflating: test_images/test_4138.jpg
#   inflating: test_images/test_4139.jpg
#   inflating: test_images/test_414.jpg
#   inflating: test_images/test_4140.jpg
#   inflating: test_images/test_4141.jpg
#   inflating: test_images/test_4142.jpg
#   inflating: test_images/test_4143.jpg
#   inflating: test_images/test_4144.jpg
#   inflating: test_images/test_4145.jpg
#   inflating: test_images/test_4146.jpg
#   inflating: test_images/test_4147.jpg
#   inflating: test_images/test_4148.jpg
#   inflating: test_images/test_4149.jpg
#   inflating: test_images/test_415.jpg
#   inflating: test_images/test_4150.jpg
#   inflating: test_images/test_4151.jpg
#   inflating: test_images/test_4152.jpg
#   inflating: test_images/test_4153.jpg
#   inflating: test_images/test_4154.jpg
#   inflating: test_images/test_4155.jpg
#   inflating: test_images/test_4156.jpg
#   inflating: test_images/test_4157.jpg
#   inflating: test_images/test_4158.jpg
#   inflating: test_images/test_4159.jpg
#   inflating: test_images/test_416.jpg
#   inflating: test_images/test_4160.jpg
#   inflating: test_images/test_4161.jpg
#   inflating: test_images/test_4162.jpg
#   inflating: test_images/test_4163.jpg
#   inflating: test_images/test_4164.jpg
#   inflating: test_images/test_4165.jpg
#   inflating: test_images/test_4166.jpg
#   inflating: test_images/test_4167.jpg
#   inflating: test_images/test_4168.jpg
#   inflating: test_images/test_4169.jpg
#   inflating: test_images/test_417.jpg
#   inflating: test_images/test_4170.jpg
#   inflating: test_images/test_4171.jpg
#   inflating: test_images/test_4172.jpg
#   inflating: test_images/test_4173.jpg
#   inflating: test_images/test_4174.jpg
#   inflating: test_images/test_4175.jpg
#   inflating: test_images/test_4176.jpg
#   inflating: test_images/test_4177.jpg
#   inflating: test_images/test_4178.jpg
#   inflating: test_images/test_4179.jpg
#   inflating: test_images/test_418.jpg
#   inflating: test_images/test_4180.jpg
#   inflating: test_images/test_4181.jpg
#   inflating: test_images/test_4182.jpg
#   inflating: test_images/test_4183.jpg
#   inflating: test_images/test_4184.jpg
#   inflating: test_images/test_4185.jpg
#   inflating: test_images/test_4186.jpg
#   inflating: test_images/test_4187.jpg
#   inflating: test_images/test_4188.jpg
#   inflating: test_images/test_4189.jpg
#   inflating: test_images/test_419.jpg
#   inflating: test_images/test_4190.jpg
#   inflating: test_images/test_4191.jpg
#   inflating: test_images/test_4192.jpg
#   inflating: test_images/test_4193.jpg
#   inflating: test_images/test_4194.jpg
#   inflating: test_images/test_4195.jpg
#   inflating: test_images/test_4196.jpg
#   inflating: test_images/test_4197.jpg
#   inflating: test_images/test_4198.jpg
#   inflating: test_images/test_4199.jpg
#   inflating: test_images/test_42.jpg
#   inflating: test_images/test_420.jpg
#   inflating: test_images/test_4200.jpg
#   inflating: test_images/test_4201.jpg
#   inflating: test_images/test_4202.jpg
#   inflating: test_images/test_4203.jpg
#   inflating: test_images/test_4204.jpg
#   inflating: test_images/test_4205.jpg
#   inflating: test_images/test_4206.jpg
#   inflating: test_images/test_4207.jpg
#   inflating: test_images/test_4208.jpg
#   inflating: test_images/test_4209.jpg
#   inflating: test_images/test_421.jpg
#   inflating: test_images/test_4210.jpg
#   inflating: test_images/test_4211.jpg
#   inflating: test_images/test_4212.jpg
#   inflating: test_images/test_4213.jpg
#   inflating: test_images/test_4214.jpg
#   inflating: test_images/test_4215.jpg
#   inflating: test_images/test_4216.jpg
#   inflating: test_images/test_4217.jpg
#   inflating: test_images/test_4218.jpg
#   inflating: test_images/test_4219.jpg
#   inflating: test_images/test_422.jpg
#   inflating: test_images/test_4220.jpg
#   inflating: test_images/test_4221.jpg
#   inflating: test_images/test_4222.jpg
#   inflating: test_images/test_4223.jpg
#   inflating: test_images/test_4224.jpg
#   inflating: test_images/test_4225.jpg
#   inflating: test_images/test_4226.jpg
#   inflating: test_images/test_4227.jpg
#   inflating: test_images/test_4228.jpg
#   inflating: test_images/test_4229.jpg
#   inflating: test_images/test_423.jpg
#   inflating: test_images/test_4230.jpg
#   inflating: test_images/test_4231.jpg
#   inflating: test_images/test_4232.jpg
#   inflating: test_images/test_4233.jpg
#   inflating: test_images/test_4234.jpg
#   inflating: test_images/test_4235.jpg
#   inflating: test_images/test_4236.jpg
#   inflating: test_images/test_4237.jpg
#   inflating: test_images/test_4238.jpg
#   inflating: test_images/test_4239.jpg
#   inflating: test_images/test_424.jpg
#   inflating: test_images/test_4240.jpg
#   inflating: test_images/test_4241.jpg
#   inflating: test_images/test_4242.jpg
#   inflating: test_images/test_4243.jpg
#   inflating: test_images/test_4244.jpg
#   inflating: test_images/test_4245.jpg
#   inflating: test_images/test_4246.jpg
#   inflating: test_images/test_4247.jpg
#   inflating: test_images/test_4248.jpg
#   inflating: test_images/test_4249.jpg
#   inflating: test_images/test_425.jpg
#   inflating: test_images/test_4250.jpg
#   inflating: test_images/test_4251.jpg
#   inflating: test_images/test_4252.jpg
#   inflating: test_images/test_4253.jpg
#   inflating: test_images/test_4254.jpg
#   inflating: test_images/test_4255.jpg
#   inflating: test_images/test_4256.jpg
#   inflating: test_images/test_4257.jpg
#   inflating: test_images/test_4258.jpg
#   inflating: test_images/test_4259.jpg
#   inflating: test_images/test_426.jpg
#   inflating: test_images/test_4260.jpg
#   inflating: test_images/test_4261.jpg
#   inflating: test_images/test_4262.jpg
#   inflating: test_images/test_4263.jpg
#   inflating: test_images/test_4264.jpg
#   inflating: test_images/test_4265.jpg
#   inflating: test_images/test_4266.jpg
#   inflating: test_images/test_4267.jpg
#   inflating: test_images/test_4268.jpg
#   inflating: test_images/test_4269.jpg
#   inflating: test_images/test_427.jpg
#   inflating: test_images/test_4270.jpg
#   inflating: test_images/test_4271.jpg
#   inflating: test_images/test_4272.jpg
#   inflating: test_images/test_4273.jpg
#   inflating: test_images/test_4274.jpg
#   inflating: test_images/test_4275.jpg
#   inflating: test_images/test_4276.jpg
#   inflating: test_images/test_4277.jpg
#   inflating: test_images/test_4278.jpg
#   inflating: test_images/test_4279.jpg
#   inflating: test_images/test_428.jpg
#   inflating: test_images/test_4280.jpg
#   inflating: test_images/test_4281.jpg
#   inflating: test_images/test_4282.jpg
#   inflating: test_images/test_4283.jpg
#   inflating: test_images/test_4284.jpg
#   inflating: test_images/test_4285.jpg
#   inflating: test_images/test_4286.jpg
#   inflating: test_images/test_4287.jpg
#   inflating: test_images/test_4288.jpg
#   inflating: test_images/test_4289.jpg
#   inflating: test_images/test_429.jpg
#   inflating: test_images/test_4290.jpg
#   inflating: test_images/test_4291.jpg
#   inflating: test_images/test_4292.jpg
#   inflating: test_images/test_4293.jpg
#   inflating: test_images/test_4294.jpg
#   inflating: test_images/test_4295.jpg
#   inflating: test_images/test_4296.jpg
#   inflating: test_images/test_4297.jpg
#   inflating: test_images/test_4298.jpg
#   inflating: test_images/test_4299.jpg
#   inflating: test_images/test_43.jpg
#   inflating: test_images/test_430.jpg
#   inflating: test_images/test_4300.jpg
#   inflating: test_images/test_4301.jpg
#   inflating: test_images/test_4302.jpg
#   inflating: test_images/test_4303.jpg
#   inflating: test_images/test_4304.jpg
#   inflating: test_images/test_4305.jpg
#   inflating: test_images/test_4306.jpg
#   inflating: test_images/test_4307.jpg
#   inflating: test_images/test_4308.jpg
#   inflating: test_images/test_4309.jpg
#   inflating: test_images/test_431.jpg
#   inflating: test_images/test_4310.jpg
#   inflating: test_images/test_4311.jpg
#   inflating: test_images/test_4312.jpg
#   inflating: test_images/test_4313.jpg
#   inflating: test_images/test_4314.jpg
#   inflating: test_images/test_4315.jpg
#   inflating: test_images/test_4316.jpg
#   inflating: test_images/test_4317.jpg
#   inflating: test_images/test_4318.jpg
#   inflating: test_images/test_4319.jpg
#   inflating: test_images/test_432.jpg
#   inflating: test_images/test_4320.jpg
#   inflating: test_images/test_4321.jpg
#   inflating: test_images/test_4322.jpg
#   inflating: test_images/test_4323.jpg
#   inflating: test_images/test_4324.jpg
#   inflating: test_images/test_4325.jpg
#   inflating: test_images/test_4326.jpg
#   inflating: test_images/test_4327.jpg
#   inflating: test_images/test_4328.jpg
#   inflating: test_images/test_4329.jpg
#   inflating: test_images/test_433.jpg
#   inflating: test_images/test_4330.jpg
#   inflating: test_images/test_4331.jpg
#   inflating: test_images/test_4332.jpg
#   inflating: test_images/test_4333.jpg
#   inflating: test_images/test_4334.jpg
#   inflating: test_images/test_4335.jpg
#   inflating: test_images/test_4336.jpg
#   inflating: test_images/test_4337.jpg
#   inflating: test_images/test_4338.jpg
#   inflating: test_images/test_4339.jpg
#   inflating: test_images/test_434.jpg
#   inflating: test_images/test_4340.jpg
#   inflating: test_images/test_4341.jpg
#   inflating: test_images/test_4342.jpg
#   inflating: test_images/test_4343.jpg
#   inflating: test_images/test_4344.jpg
#   inflating: test_images/test_4345.jpg
#   inflating: test_images/test_4346.jpg
#   inflating: test_images/test_4347.jpg
#   inflating: test_images/test_4348.jpg
#   inflating: test_images/test_4349.jpg
#   inflating: test_images/test_435.jpg
#   inflating: test_images/test_4350.jpg
#   inflating: test_images/test_4351.jpg
#   inflating: test_images/test_4352.jpg
#   inflating: test_images/test_4353.jpg
#   inflating: test_images/test_4354.jpg
#   inflating: test_images/test_4355.jpg
#   inflating: test_images/test_4356.jpg
#   inflating: test_images/test_4357.jpg
#   inflating: test_images/test_4358.jpg
#   inflating: test_images/test_4359.jpg
#   inflating: test_images/test_436.jpg
#   inflating: test_images/test_4360.jpg
#   inflating: test_images/test_4361.jpg
#   inflating: test_images/test_4362.jpg
#   inflating: test_images/test_4363.jpg
#   inflating: test_images/test_4364.jpg
#   inflating: test_images/test_4365.jpg
#   inflating: test_images/test_4366.jpg
#   inflating: test_images/test_4367.jpg
#   inflating: test_images/test_4368.jpg
#   inflating: test_images/test_4369.jpg
#   inflating: test_images/test_437.jpg
#   inflating: test_images/test_4370.jpg
#   inflating: test_images/test_4371.jpg
#   inflating: test_images/test_4372.jpg
#   inflating: test_images/test_4373.jpg
#   inflating: test_images/test_4374.jpg
#   inflating: test_images/test_4375.jpg
#   inflating: test_images/test_4376.jpg
#   inflating: test_images/test_4377.jpg
#   inflating: test_images/test_4378.jpg
#   inflating: test_images/test_4379.jpg
#   inflating: test_images/test_438.jpg
#   inflating: test_images/test_4380.jpg
#   inflating: test_images/test_4381.jpg
#   inflating: test_images/test_4382.jpg
#   inflating: test_images/test_4383.jpg
#   inflating: test_images/test_4384.jpg
#   inflating: test_images/test_4385.jpg
#   inflating: test_images/test_4386.jpg
#   inflating: test_images/test_4387.jpg
#   inflating: test_images/test_4388.jpg
#   inflating: test_images/test_4389.jpg
#   inflating: test_images/test_439.jpg
#   inflating: test_images/test_4390.jpg
#   inflating: test_images/test_4391.jpg
#   inflating: test_images/test_4392.jpg
#   inflating: test_images/test_4393.jpg
#   inflating: test_images/test_4394.jpg
#   inflating: test_images/test_4395.jpg
#   inflating: test_images/test_4396.jpg
#   inflating: test_images/test_4397.jpg
#   inflating: test_images/test_4398.jpg
#   inflating: test_images/test_4399.jpg
#   inflating: test_images/test_44.jpg
#   inflating: test_images/test_440.jpg
#   inflating: test_images/test_4400.jpg
#   inflating: test_images/test_4401.jpg
#   inflating: test_images/test_4402.jpg
#   inflating: test_images/test_4403.jpg
#   inflating: test_images/test_4404.jpg
#   inflating: test_images/test_4405.jpg
#   inflating: test_images/test_4406.jpg
#   inflating: test_images/test_4407.jpg
#   inflating: test_images/test_4408.jpg
#   inflating: test_images/test_4409.jpg
#   inflating: test_images/test_441.jpg
#   inflating: test_images/test_4410.jpg
#   inflating: test_images/test_4411.jpg
#   inflating: test_images/test_4412.jpg
#   inflating: test_images/test_4413.jpg
#   inflating: test_images/test_4414.jpg
#   inflating: test_images/test_4415.jpg
#   inflating: test_images/test_4416.jpg
#   inflating: test_images/test_4417.jpg
#   inflating: test_images/test_4418.jpg
#   inflating: test_images/test_4419.jpg
#   inflating: test_images/test_442.jpg
#   inflating: test_images/test_4420.jpg
#   inflating: test_images/test_4421.jpg
#   inflating: test_images/test_4422.jpg
#   inflating: test_images/test_4423.jpg
#   inflating: test_images/test_4424.jpg
#   inflating: test_images/test_4425.jpg
#   inflating: test_images/test_4426.jpg
#   inflating: test_images/test_4427.jpg
#   inflating: test_images/test_4428.jpg
#   inflating: test_images/test_4429.jpg
#   inflating: test_images/test_443.jpg
#   inflating: test_images/test_4430.jpg
#   inflating: test_images/test_4431.jpg
#   inflating: test_images/test_4432.jpg
#   inflating: test_images/test_4433.jpg
#   inflating: test_images/test_4434.jpg
#   inflating: test_images/test_4435.jpg
#   inflating: test_images/test_4436.jpg
#   inflating: test_images/test_4437.jpg
#   inflating: test_images/test_4438.jpg
#   inflating: test_images/test_4439.jpg
#   inflating: test_images/test_444.jpg
#   inflating: test_images/test_4440.jpg
#   inflating: test_images/test_4441.jpg
#   inflating: test_images/test_4442.jpg
#   inflating: test_images/test_4443.jpg
#   inflating: test_images/test_4444.jpg
#   inflating: test_images/test_4445.jpg
#   inflating: test_images/test_4446.jpg
#   inflating: test_images/test_4447.jpg
#   inflating: test_images/test_4448.jpg
#   inflating: test_images/test_4449.jpg
#   inflating: test_images/test_445.jpg
#   inflating: test_images/test_4450.jpg
#   inflating: test_images/test_4451.jpg
#   inflating: test_images/test_4452.jpg
#   inflating: test_images/test_4453.jpg
#   inflating: test_images/test_4454.jpg
#   inflating: test_images/test_4455.jpg
#   inflating: test_images/test_4456.jpg
#   inflating: test_images/test_4457.jpg
#   inflating: test_images/test_4458.jpg
#   inflating: test_images/test_4459.jpg
#   inflating: test_images/test_446.jpg
#   inflating: test_images/test_4460.jpg
#   inflating: test_images/test_4461.jpg
#   inflating: test_images/test_4462.jpg
#   inflating: test_images/test_4463.jpg
#   inflating: test_images/test_4464.jpg
#   inflating: test_images/test_4465.jpg
#   inflating: test_images/test_4466.jpg
#   inflating: test_images/test_4467.jpg
#   inflating: test_images/test_4468.jpg
#   inflating: test_images/test_4469.jpg
#   inflating: test_images/test_447.jpg
#   inflating: test_images/test_4470.jpg
#   inflating: test_images/test_4471.jpg
#   inflating: test_images/test_4472.jpg
#   inflating: test_images/test_4473.jpg
#   inflating: test_images/test_4474.jpg
#   inflating: test_images/test_4475.jpg
#   inflating: test_images/test_4476.jpg
#   inflating: test_images/test_4477.jpg
#   inflating: test_images/test_4478.jpg
#   inflating: test_images/test_4479.jpg
#   inflating: test_images/test_448.jpg
#   inflating: test_images/test_4480.jpg
#   inflating: test_images/test_4481.jpg
#   inflating: test_images/test_4482.jpg
#   inflating: test_images/test_4483.jpg
#   inflating: test_images/test_4484.jpg
#   inflating: test_images/test_4485.jpg
#   inflating: test_images/test_4486.jpg
#   inflating: test_images/test_4487.jpg
#   inflating: test_images/test_4488.jpg
#   inflating: test_images/test_4489.jpg
#   inflating: test_images/test_449.jpg
#   inflating: test_images/test_4490.jpg
#   inflating: test_images/test_4491.jpg
#   inflating: test_images/test_4492.jpg
#   inflating: test_images/test_4493.jpg
#   inflating: test_images/test_4494.jpg
#   inflating: test_images/test_4495.jpg
#   inflating: test_images/test_4496.jpg
#   inflating: test_images/test_4497.jpg
#   inflating: test_images/test_4498.jpg
#   inflating: test_images/test_4499.jpg
#   inflating: test_images/test_45.jpg
#   inflating: test_images/test_450.jpg
#   inflating: test_images/test_4500.jpg
#   inflating: test_images/test_4501.jpg
#   inflating: test_images/test_4502.jpg
#   inflating: test_images/test_4503.jpg
#   inflating: test_images/test_4504.jpg
#   inflating: test_images/test_4505.jpg
#   inflating: test_images/test_4506.jpg
#   inflating: test_images/test_4507.jpg
#   inflating: test_images/test_4508.jpg
#   inflating: test_images/test_4509.jpg
#   inflating: test_images/test_451.jpg
#   inflating: test_images/test_4510.jpg
#   inflating: test_images/test_4511.jpg
#   inflating: test_images/test_4512.jpg
#   inflating: test_images/test_4513.jpg
#   inflating: test_images/test_4514.jpg
#   inflating: test_images/test_4515.jpg
#   inflating: test_images/test_4516.jpg
#   inflating: test_images/test_4517.jpg
#   inflating: test_images/test_4518.jpg
#   inflating: test_images/test_4519.jpg
#   inflating: test_images/test_452.jpg
#   inflating: test_images/test_4520.jpg
#   inflating: test_images/test_4521.jpg
#   inflating: test_images/test_4522.jpg
#   inflating: test_images/test_4523.jpg
#   inflating: test_images/test_4524.jpg
#   inflating: test_images/test_4525.jpg
#   inflating: test_images/test_4526.jpg
#   inflating: test_images/test_4527.jpg
#   inflating: test_images/test_4528.jpg
#   inflating: test_images/test_4529.jpg
#   inflating: test_images/test_453.jpg
#   inflating: test_images/test_4530.jpg
#   inflating: test_images/test_4531.jpg
#   inflating: test_images/test_4532.jpg
#   inflating: test_images/test_4533.jpg
#   inflating: test_images/test_4534.jpg
#   inflating: test_images/test_4535.jpg
#   inflating: test_images/test_4536.jpg
#   inflating: test_images/test_4537.jpg
#   inflating: test_images/test_4538.jpg
#   inflating: test_images/test_4539.jpg
#   inflating: test_images/test_454.jpg
#   inflating: test_images/test_4540.jpg
#   inflating: test_images/test_4541.jpg
#   inflating: test_images/test_4542.jpg
#   inflating: test_images/test_4543.jpg
#   inflating: test_images/test_4544.jpg
#   inflating: test_images/test_4545.jpg
#   inflating: test_images/test_4546.jpg
#   inflating: test_images/test_4547.jpg
#   inflating: test_images/test_4548.jpg
#   inflating: test_images/test_4549.jpg
#   inflating: test_images/test_455.jpg
#   inflating: test_images/test_4550.jpg
#   inflating: test_images/test_4551.jpg
#   inflating: test_images/test_4552.jpg
#   inflating: test_images/test_4553.jpg
#   inflating: test_images/test_4554.jpg
#   inflating: test_images/test_4555.jpg
#   inflating: test_images/test_4556.jpg
#   inflating: test_images/test_4557.jpg
#   inflating: test_images/test_4558.jpg
#   inflating: test_images/test_4559.jpg
#   inflating: test_images/test_456.jpg
#   inflating: test_images/test_4560.jpg
#   inflating: test_images/test_4561.jpg
#   inflating: test_images/test_4562.jpg
#   inflating: test_images/test_4563.jpg
#   inflating: test_images/test_4564.jpg
#   inflating: test_images/test_4565.jpg
#   inflating: test_images/test_4566.jpg
#   inflating: test_images/test_4567.jpg
#   inflating: test_images/test_4568.jpg
#   inflating: test_images/test_4569.jpg
#   inflating: test_images/test_457.jpg
#   inflating: test_images/test_4570.jpg
#   inflating: test_images/test_4571.jpg
#   inflating: test_images/test_4572.jpg
#   inflating: test_images/test_4573.jpg
#   inflating: test_images/test_4574.jpg
#   inflating: test_images/test_4575.jpg
#   inflating: test_images/test_4576.jpg
#   inflating: test_images/test_4577.jpg
#   inflating: test_images/test_4578.jpg
#   inflating: test_images/test_4579.jpg
#   inflating: test_images/test_458.jpg
#   inflating: test_images/test_4580.jpg
#   inflating: test_images/test_4581.jpg
#   inflating: test_images/test_4582.jpg
#   inflating: test_images/test_4583.jpg
#   inflating: test_images/test_4584.jpg
#   inflating: test_images/test_4585.jpg
#   inflating: test_images/test_4586.jpg
#   inflating: test_images/test_4587.jpg
#   inflating: test_images/test_4588.jpg
#   inflating: test_images/test_4589.jpg
#   inflating: test_images/test_459.jpg
#   inflating: test_images/test_4590.jpg
#   inflating: test_images/test_4591.jpg
#   inflating: test_images/test_4592.jpg
#   inflating: test_images/test_4593.jpg
#   inflating: test_images/test_4594.jpg
#   inflating: test_images/test_4595.jpg
#   inflating: test_images/test_4596.jpg
#   inflating: test_images/test_4597.jpg
#   inflating: test_images/test_4598.jpg
#   inflating: test_images/test_4599.jpg
#   inflating: test_images/test_46.jpg
#   inflating: test_images/test_460.jpg
#   inflating: test_images/test_4600.jpg
#   inflating: test_images/test_4601.jpg
#   inflating: test_images/test_4602.jpg
#   inflating: test_images/test_4603.jpg
#   inflating: test_images/test_4604.jpg
#   inflating: test_images/test_4605.jpg
#   inflating: test_images/test_4606.jpg
#   inflating: test_images/test_4607.jpg
#   inflating: test_images/test_4608.jpg
#   inflating: test_images/test_4609.jpg
#   inflating: test_images/test_461.jpg
#   inflating: test_images/test_4610.jpg
#   inflating: test_images/test_4611.jpg
#   inflating: test_images/test_4612.jpg
#   inflating: test_images/test_4613.jpg
#   inflating: test_images/test_4614.jpg
#   inflating: test_images/test_4615.jpg
#   inflating: test_images/test_4616.jpg
#   inflating: test_images/test_4617.jpg
#   inflating: test_images/test_4618.jpg
#   inflating: test_images/test_4619.jpg
#   inflating: test_images/test_462.jpg
#   inflating: test_images/test_4620.jpg
#   inflating: test_images/test_4621.jpg
#   inflating: test_images/test_4622.jpg
#   inflating: test_images/test_4623.jpg
#   inflating: test_images/test_4624.jpg
#   inflating: test_images/test_4625.jpg
#   inflating: test_images/test_4626.jpg
#   inflating: test_images/test_4627.jpg
#   inflating: test_images/test_4628.jpg
#   inflating: test_images/test_4629.jpg
#   inflating: test_images/test_463.jpg
#   inflating: test_images/test_4630.jpg
#   inflating: test_images/test_4631.jpg
#   inflating: test_images/test_4632.jpg
#   inflating: test_images/test_4633.jpg
#   inflating: test_images/test_4634.jpg
#   inflating: test_images/test_4635.jpg
#   inflating: test_images/test_4636.jpg
#   inflating: test_images/test_4637.jpg
#   inflating: test_images/test_4638.jpg
#   inflating: test_images/test_4639.jpg
#   inflating: test_images/test_464.jpg
#   inflating: test_images/test_4640.jpg
#   inflating: test_images/test_4641.jpg
#   inflating: test_images/test_4642.jpg
#   inflating: test_images/test_4643.jpg
#   inflating: test_images/test_4644.jpg
#   inflating: test_images/test_4645.jpg
#   inflating: test_images/test_4646.jpg
#   inflating: test_images/test_4647.jpg
#   inflating: test_images/test_4648.jpg
#   inflating: test_images/test_4649.jpg
#   inflating: test_images/test_465.jpg
#   inflating: test_images/test_4650.jpg
#   inflating: test_images/test_4651.jpg
#   inflating: test_images/test_4652.jpg
#   inflating: test_images/test_4653.jpg
#   inflating: test_images/test_4654.jpg
#   inflating: test_images/test_4655.jpg
#   inflating: test_images/test_4656.jpg
#   inflating: test_images/test_4657.jpg
#   inflating: test_images/test_4658.jpg
#   inflating: test_images/test_4659.jpg
#   inflating: test_images/test_466.jpg
#   inflating: test_images/test_4660.jpg
#   inflating: test_images/test_4661.jpg
#   inflating: test_images/test_4662.jpg
#   inflating: test_images/test_4663.jpg
#   inflating: test_images/test_4664.jpg
#   inflating: test_images/test_4665.jpg
#   inflating: test_images/test_4666.jpg
#   inflating: test_images/test_4667.jpg
#   inflating: test_images/test_4668.jpg
#   inflating: test_images/test_4669.jpg
#   inflating: test_images/test_467.jpg
#   inflating: test_images/test_4670.jpg
#   inflating: test_images/test_4671.jpg
#   inflating: test_images/test_4672.jpg
#   inflating: test_images/test_4673.jpg
#   inflating: test_images/test_4674.jpg
#   inflating: test_images/test_4675.jpg
#   inflating: test_images/test_4676.jpg
#   inflating: test_images/test_4677.jpg
#   inflating: test_images/test_4678.jpg
#   inflating: test_images/test_4679.jpg
#   inflating: test_images/test_468.jpg
#   inflating: test_images/test_4680.jpg
#   inflating: test_images/test_4681.jpg
#   inflating: test_images/test_4682.jpg
#   inflating: test_images/test_4683.jpg
#   inflating: test_images/test_4684.jpg
#   inflating: test_images/test_4685.jpg
#   inflating: test_images/test_4686.jpg
#   inflating: test_images/test_4687.jpg
#   inflating: test_images/test_4688.jpg
#   inflating: test_images/test_4689.jpg
#   inflating: test_images/test_469.jpg
#   inflating: test_images/test_4690.jpg
#   inflating: test_images/test_4691.jpg
#   inflating: test_images/test_4692.jpg
#   inflating: test_images/test_4693.jpg
#   inflating: test_images/test_4694.jpg
#   inflating: test_images/test_4695.jpg
#   inflating: test_images/test_4696.jpg
#   inflating: test_images/test_4697.jpg
#   inflating: test_images/test_4698.jpg
#   inflating: test_images/test_4699.jpg
#   inflating: test_images/test_47.jpg
#   inflating: test_images/test_470.jpg
#   inflating: test_images/test_4700.jpg
#   inflating: test_images/test_4701.jpg
#   inflating: test_images/test_4702.jpg
#   inflating: test_images/test_4703.jpg
#   inflating: test_images/test_4704.jpg
#   inflating: test_images/test_4705.jpg
#   inflating: test_images/test_4706.jpg
#   inflating: test_images/test_4707.jpg
#   inflating: test_images/test_4708.jpg
#   inflating: test_images/test_4709.jpg
#   inflating: test_images/test_471.jpg
#   inflating: test_images/test_4710.jpg
#   inflating: test_images/test_4711.jpg
#   inflating: test_images/test_4712.jpg
#   inflating: test_images/test_4713.jpg
#   inflating: test_images/test_4714.jpg
#   inflating: test_images/test_4715.jpg
#   inflating: test_images/test_4716.jpg
#   inflating: test_images/test_4717.jpg
#   inflating: test_images/test_4718.jpg
#   inflating: test_images/test_4719.jpg
#   inflating: test_images/test_472.jpg
#   inflating: test_images/test_4720.jpg
#   inflating: test_images/test_4721.jpg
#   inflating: test_images/test_4722.jpg
#   inflating: test_images/test_4723.jpg
#   inflating: test_images/test_4724.jpg
#   inflating: test_images/test_4725.jpg
#   inflating: test_images/test_4726.jpg
#   inflating: test_images/test_4727.jpg
#   inflating: test_images/test_4728.jpg
#   inflating: test_images/test_4729.jpg
#   inflating: test_images/test_473.jpg
#   inflating: test_images/test_4730.jpg
#   inflating: test_images/test_4731.jpg
#   inflating: test_images/test_4732.jpg
#   inflating: test_images/test_4733.jpg
#   inflating: test_images/test_4734.jpg
#   inflating: test_images/test_4735.jpg
#   inflating: test_images/test_4736.jpg
#   inflating: test_images/test_4737.jpg
#   inflating: test_images/test_4738.jpg
#   inflating: test_images/test_4739.jpg
#   inflating: test_images/test_474.jpg
#   inflating: test_images/test_4740.jpg
#   inflating: test_images/test_4741.jpg
#   inflating: test_images/test_4742.jpg
#   inflating: test_images/test_4743.jpg
#   inflating: test_images/test_4744.jpg
#   inflating: test_images/test_4745.jpg
#   inflating: test_images/test_4746.jpg
#   inflating: test_images/test_4747.jpg
#   inflating: test_images/test_4748.jpg
#   inflating: test_images/test_4749.jpg
#   inflating: test_images/test_475.jpg
#   inflating: test_images/test_4750.jpg
#   inflating: test_images/test_4751.jpg
#   inflating: test_images/test_4752.jpg
#   inflating: test_images/test_4753.jpg
# ...
#   inflating: test_images/test_7842.jpg
#   inflating: test_images/test_7843.jpg
#   inflating: test_images/test_7844.jpg
#   inflating: test_images/test_7845.jpg
#   inflating: test_images/test_7846.jpg
#   inflating: test_images/test_7847.jpg
#   inflating: test_images/test_7848.jpg
#   inflating: test_images/test_7849.jpg
#   inflating: test_images/test_785.jpg
#   inflating: test_images/test_7850.jpg
#   inflating: test_images/test_7851.jpg
#   inflating: test_images/test_7852.jpg
#   inflating: test_images/test_7853.jpg
#   inflating: test_images/test_7854.jpg
#   inflating: test_images/test_7855.jpg
#   inflating: test_images/test_7856.jpg
#   inflating: test_images/test_7857.jpg
#   inflating: test_images/test_7858.jpg
#   inflating: test_images/test_7859.jpg
#   inflating: test_images/test_786.jpg
#   inflating: test_images/test_7860.jpg
#   inflating: test_images/test_7861.jpg
#   inflating: test_images/test_7862.jpg
#   inflating: test_images/test_7863.jpg
#   inflating: test_images/test_7864.jpg
#   inflating: test_images/test_7865.jpg
#   inflating: test_images/test_7866.jpg
#   inflating: test_images/test_7867.jpg
#   inflating: test_images/test_7868.jpg
#   inflating: test_images/test_7869.jpg
#   inflating: test_images/test_787.jpg
#   inflating: test_images/test_7870.jpg
#   inflating: test_images/test_7871.jpg
#   inflating: test_images/test_7872.jpg
#   inflating: test_images/test_7873.jpg
#   inflating: test_images/test_7874.jpg
#   inflating: test_images/test_7875.jpg
#   inflating: test_images/test_7876.jpg
#   inflating: test_images/test_7877.jpg
#   inflating: test_images/test_7878.jpg
#   inflating: test_images/test_7879.jpg
#   inflating: test_images/test_788.jpg
#   inflating: test_images/test_7880.jpg
#   inflating: test_images/test_7881.jpg
#   inflating: test_images/test_7882.jpg
#   inflating: test_images/test_7883.jpg
#   inflating: test_images/test_7884.jpg
#   inflating: test_images/test_7885.jpg
#   inflating: test_images/test_7886.jpg
#   inflating: test_images/test_7887.jpg
#   inflating: test_images/test_7888.jpg
#   inflating: test_images/test_7889.jpg
#   inflating: test_images/test_789.jpg
#   inflating: test_images/test_7890.jpg
#   inflating: test_images/test_7891.jpg
#   inflating: test_images/test_7892.jpg
#   inflating: test_images/test_7893.jpg
#   inflating: test_images/test_7894.jpg
#   inflating: test_images/test_7895.jpg
#   inflating: test_images/test_7896.jpg
#   inflating: test_images/test_7897.jpg
#   inflating: test_images/test_7898.jpg
#   inflating: test_images/test_7899.jpg
#   inflating: test_images/test_79.jpg
#   inflating: test_images/test_790.jpg
#   inflating: test_images/test_7900.jpg
#   inflating: test_images/test_7901.jpg
#   inflating: test_images/test_7902.jpg
#   inflating: test_images/test_7903.jpg
#   inflating: test_images/test_7904.jpg
#   inflating: test_images/test_7905.jpg
#   inflating: test_images/test_7906.jpg
#   inflating: test_images/test_7907.jpg
#   inflating: test_images/test_7908.jpg
#   inflating: test_images/test_7909.jpg
#   inflating: test_images/test_791.jpg
#   inflating: test_images/test_7910.jpg
#   inflating: test_images/test_7911.jpg
#   inflating: test_images/test_7912.jpg
#   inflating: test_images/test_7913.jpg
#   inflating: test_images/test_7914.jpg
#   inflating: test_images/test_7915.jpg
#   inflating: test_images/test_7916.jpg
#   inflating: test_images/test_7917.jpg
#   inflating: test_images/test_7918.jpg
#   inflating: test_images/test_7919.jpg
#   inflating: test_images/test_792.jpg
#   inflating: test_images/test_7920.jpg
#   inflating: test_images/test_7921.jpg
#   inflating: test_images/test_7922.jpg
#   inflating: test_images/test_7923.jpg
#   inflating: test_images/test_7924.jpg
#   inflating: test_images/test_7925.jpg
#   inflating: test_images/test_7926.jpg
#   inflating: test_images/test_7927.jpg
#   inflating: test_images/test_7928.jpg
#   inflating: test_images/test_7929.jpg
#   inflating: test_images/test_793.jpg
#   inflating: test_images/test_7930.jpg
#   inflating: test_images/test_7931.jpg
#   inflating: test_images/test_7932.jpg
#   inflating: test_images/test_7933.jpg
#   inflating: test_images/test_7934.jpg
#   inflating: test_images/test_7935.jpg
#   inflating: test_images/test_7936.jpg
#   inflating: test_images/test_7937.jpg
#   inflating: test_images/test_7938.jpg
#   inflating: test_images/test_7939.jpg
#   inflating: test_images/test_794.jpg
#   inflating: test_images/test_7940.jpg
#   inflating: test_images/test_7941.jpg
#   inflating: test_images/test_7942.jpg
#   inflating: test_images/test_7943.jpg
#   inflating: test_images/test_7944.jpg
#   inflating: test_images/test_7945.jpg
#   inflating: test_images/test_7946.jpg
#   inflating: test_images/test_7947.jpg
#   inflating: test_images/test_7948.jpg
#   inflating: test_images/test_7949.jpg
#   inflating: test_images/test_795.jpg
#   inflating: test_images/test_7950.jpg
#   inflating: test_images/test_7951.jpg
#   inflating: test_images/test_7952.jpg
#   inflating: test_images/test_7953.jpg
#   inflating: test_images/test_7954.jpg
#   inflating: test_images/test_7955.jpg
#   inflating: test_images/test_7956.jpg
#   inflating: test_images/test_7957.jpg
#   inflating: test_images/test_7958.jpg
#   inflating: test_images/test_7959.jpg
#   inflating: test_images/test_796.jpg
#   inflating: test_images/test_7960.jpg
#   inflating: test_images/test_7961.jpg
#   inflating: test_images/test_7962.jpg
#   inflating: test_images/test_7963.jpg
#   inflating: test_images/test_7964.jpg
#   inflating: test_images/test_7965.jpg
#   inflating: test_images/test_7966.jpg
#   inflating: test_images/test_7967.jpg
#   inflating: test_images/test_7968.jpg
#   inflating: test_images/test_7969.jpg
#   inflating: test_images/test_797.jpg
#   inflating: test_images/test_7970.jpg
#   inflating: test_images/test_7971.jpg
#   inflating: test_images/test_7972.jpg
#   inflating: test_images/test_7973.jpg
#   inflating: test_images/test_7974.jpg
#   inflating: test_images/test_7975.jpg
#   inflating: test_images/test_7976.jpg
#   inflating: test_images/test_7977.jpg
#   inflating: test_images/test_7978.jpg
#   inflating: test_images/test_7979.jpg
#   inflating: test_images/test_798.jpg
#   inflating: test_images/test_7980.jpg
#   inflating: test_images/test_7981.jpg
#   inflating: test_images/test_7982.jpg
#   inflating: test_images/test_7983.jpg
#   inflating: test_images/test_7984.jpg
#   inflating: test_images/test_7985.jpg
#   inflating: test_images/test_7986.jpg
#   inflating: test_images/test_7987.jpg
#   inflating: test_images/test_7988.jpg
#   inflating: test_images/test_7989.jpg
#   inflating: test_images/test_799.jpg
#   inflating: test_images/test_7990.jpg
#   inflating: test_images/test_7991.jpg
#   inflating: test_images/test_7992.jpg
#   inflating: test_images/test_7993.jpg
#   inflating: test_images/test_7994.jpg
#   inflating: test_images/test_7995.jpg
#   inflating: test_images/test_7996.jpg
#   inflating: test_images/test_7997.jpg
#   inflating: test_images/test_7998.jpg
#   inflating: test_images/test_7999.jpg
#   inflating: test_images/test_8.jpg
#   inflating: test_images/test_80.jpg
#   inflating: test_images/test_800.jpg
#   inflating: test_images/test_801.jpg
#   inflating: test_images/test_802.jpg
#   inflating: test_images/test_803.jpg
#   inflating: test_images/test_804.jpg
#   inflating: test_images/test_805.jpg
#   inflating: test_images/test_806.jpg
#   inflating: test_images/test_807.jpg
#   inflating: test_images/test_808.jpg
#   inflating: test_images/test_809.jpg
#   inflating: test_images/test_81.jpg
#   inflating: test_images/test_810.jpg
#   inflating: test_images/test_811.jpg
#   inflating: test_images/test_812.jpg
#   inflating: test_images/test_813.jpg
#   inflating: test_images/test_814.jpg
#   inflating: test_images/test_815.jpg
#   inflating: test_images/test_816.jpg
#   inflating: test_images/test_817.jpg
#   inflating: test_images/test_818.jpg
#   inflating: test_images/test_819.jpg
#   inflating: test_images/test_82.jpg
#   inflating: test_images/test_820.jpg
#   inflating: test_images/test_821.jpg
#   inflating: test_images/test_822.jpg
#   inflating: test_images/test_823.jpg
#   inflating: test_images/test_824.jpg
#   inflating: test_images/test_825.jpg
#   inflating: test_images/test_826.jpg
#   inflating: test_images/test_827.jpg
#   inflating: test_images/test_828.jpg
#   inflating: test_images/test_829.jpg
#   inflating: test_images/test_83.jpg
#   inflating: test_images/test_830.jpg
#   inflating: test_images/test_831.jpg
#   inflating: test_images/test_832.jpg
#   inflating: test_images/test_833.jpg
#   inflating: test_images/test_834.jpg
#   inflating: test_images/test_835.jpg
#   inflating: test_images/test_836.jpg
#   inflating: test_images/test_837.jpg
#   inflating: test_images/test_838.jpg
#   inflating: test_images/test_839.jpg
#   inflating: test_images/test_84.jpg
#   inflating: test_images/test_840.jpg
#   inflating: test_images/test_841.jpg
#   inflating: test_images/test_842.jpg
#   inflating: test_images/test_843.jpg
#   inflating: test_images/test_844.jpg
#   inflating: test_images/test_845.jpg
#   inflating: test_images/test_846.jpg
#   inflating: test_images/test_847.jpg
#   inflating: test_images/test_848.jpg
#   inflating: test_images/test_849.jpg
#   inflating: test_images/test_85.jpg
#   inflating: test_images/test_850.jpg
#   inflating: test_images/test_851.jpg
#   inflating: test_images/test_852.jpg
#   inflating: test_images/test_853.jpg
#   inflating: test_images/test_854.jpg
#   inflating: test_images/test_855.jpg
#   inflating: test_images/test_856.jpg
#   inflating: test_images/test_857.jpg
#   inflating: test_images/test_858.jpg
#   inflating: test_images/test_859.jpg
#   inflating: test_images/test_86.jpg
#   inflating: test_images/test_860.jpg
#   inflating: test_images/test_861.jpg
#   inflating: test_images/test_862.jpg
#   inflating: test_images/test_863.jpg
#   inflating: test_images/test_864.jpg
#   inflating: test_images/test_865.jpg
#   inflating: test_images/test_866.jpg
#   inflating: test_images/test_867.jpg
#   inflating: test_images/test_868.jpg
#   inflating: test_images/test_869.jpg
#   inflating: test_images/test_87.jpg
#   inflating: test_images/test_870.jpg
#   inflating: test_images/test_871.jpg
#   inflating: test_images/test_872.jpg
#   inflating: test_images/test_873.jpg
#   inflating: test_images/test_874.jpg
#   inflating: test_images/test_875.jpg
#   inflating: test_images/test_876.jpg
#   inflating: test_images/test_877.jpg
#   inflating: test_images/test_878.jpg
#   inflating: test_images/test_879.jpg
#   inflating: test_images/test_88.jpg
#   inflating: test_images/test_880.jpg
#   inflating: test_images/test_881.jpg
#   inflating: test_images/test_882.jpg
#   inflating: test_images/test_883.jpg
#   inflating: test_images/test_884.jpg
#   inflating: test_images/test_885.jpg
#   inflating: test_images/test_886.jpg
#   inflating: test_images/test_887.jpg
#   inflating: test_images/test_888.jpg
#   inflating: test_images/test_889.jpg
#   inflating: test_images/test_89.jpg
#   inflating: test_images/test_890.jpg
#   inflating: test_images/test_891.jpg
#   inflating: test_images/test_892.jpg
#   inflating: test_images/test_893.jpg
#   inflating: test_images/test_894.jpg
#   inflating: test_images/test_895.jpg
#   inflating: test_images/test_896.jpg
#   inflating: test_images/test_897.jpg
#   inflating: test_images/test_898.jpg
#   inflating: test_images/test_899.jpg
#   inflating: test_images/test_9.jpg
#   inflating: test_images/test_90.jpg
#   inflating: test_images/test_900.jpg
#   inflating: test_images/test_901.jpg
#   inflating: test_images/test_902.jpg
#   inflating: test_images/test_903.jpg
#   inflating: test_images/test_904.jpg
#   inflating: test_images/test_905.jpg
#   inflating: test_images/test_906.jpg
#   inflating: test_images/test_907.jpg
#   inflating: test_images/test_908.jpg
#   inflating: test_images/test_909.jpg
#   inflating: test_images/test_91.jpg
#   inflating: test_images/test_910.jpg
#   inflating: test_images/test_911.jpg
#   inflating: test_images/test_912.jpg
#   inflating: test_images/test_913.jpg
#   inflating: test_images/test_914.jpg
#   inflating: test_images/test_915.jpg
#   inflating: test_images/test_916.jpg
#   inflating: test_images/test_917.jpg
#   inflating: test_images/test_918.jpg
#   inflating: test_images/test_919.jpg
#   inflating: test_images/test_92.jpg
#   inflating: test_images/test_920.jpg
#   inflating: test_images/test_921.jpg
#   inflating: test_images/test_922.jpg
#   inflating: test_images/test_923.jpg
#   inflating: test_images/test_924.jpg
#   inflating: test_images/test_925.jpg
#   inflating: test_images/test_926.jpg
#   inflating: test_images/test_927.jpg
#   inflating: test_images/test_928.jpg
#   inflating: test_images/test_929.jpg
#   inflating: test_images/test_93.jpg
#   inflating: test_images/test_930.jpg
#   inflating: test_images/test_931.jpg
#   inflating: test_images/test_932.jpg
#   inflating: test_images/test_933.jpg
#   inflating: test_images/test_934.jpg
#   inflating: test_images/test_935.jpg
#   inflating: test_images/test_936.jpg
#   inflating: test_images/test_937.jpg
#   inflating: test_images/test_938.jpg
#   inflating: test_images/test_939.jpg
#   inflating: test_images/test_94.jpg
#   inflating: test_images/test_940.jpg
#   inflating: test_images/test_941.jpg
#   inflating: test_images/test_942.jpg
#   inflating: test_images/test_943.jpg
#   inflating: test_images/test_944.jpg
#   inflating: test_images/test_945.jpg
#   inflating: test_images/test_946.jpg
#   inflating: test_images/test_947.jpg
#   inflating: test_images/test_948.jpg
#   inflating: test_images/test_949.jpg
#   inflating: test_images/test_95.jpg
#   inflating: test_images/test_950.jpg
#   inflating: test_images/test_951.jpg
#   inflating: test_images/test_952.jpg
#   inflating: test_images/test_953.jpg
#   inflating: test_images/test_954.jpg
#   inflating: test_images/test_955.jpg
#   inflating: test_images/test_956.jpg
#   inflating: test_images/test_957.jpg
#   inflating: test_images/test_958.jpg
#   inflating: test_images/test_959.jpg
#   inflating: test_images/test_96.jpg
#   inflating: test_images/test_960.jpg
#   inflating: test_images/test_961.jpg
#   inflating: test_images/test_962.jpg
#   inflating: test_images/test_963.jpg
#   inflating: test_images/test_964.jpg
#   inflating: test_images/test_965.jpg
#   inflating: test_images/test_966.jpg
#   inflating: test_images/test_967.jpg
#   inflating: test_images/test_968.jpg
#   inflating: test_images/test_969.jpg
#   inflating: test_images/test_97.jpg
#   inflating: test_images/test_970.jpg
#   inflating: test_images/test_971.jpg
#   inflating: test_images/test_972.jpg
#   inflating: test_images/test_973.jpg
#   inflating: test_images/test_974.jpg
#   inflating: test_images/test_975.jpg
#   inflating: test_images/test_976.jpg
#   inflating: test_images/test_977.jpg
#   inflating: test_images/test_978.jpg
#   inflating: test_images/test_979.jpg
#   inflating: test_images/test_98.jpg
#   inflating: test_images/test_980.jpg
#   inflating: test_images/test_981.jpg
#   inflating: test_images/test_982.jpg
#   inflating: test_images/test_983.jpg
#   inflating: test_images/test_984.jpg
#   inflating: test_images/test_985.jpg
#   inflating: test_images/test_986.jpg
#   inflating: test_images/test_987.jpg
#   inflating: test_images/test_988.jpg
#   inflating: test_images/test_989.jpg
#   inflating: test_images/test_99.jpg
#   inflating: test_images/test_990.jpg
#   inflating: test_images/test_991.jpg
#   inflating: test_images/test_992.jpg
#   inflating: test_images/test_993.jpg
#   inflating: test_images/test_994.jpg
#   inflating: test_images/test_995.jpg
#   inflating: test_images/test_996.jpg
#   inflating: test_images/test_997.jpg
#   inflating: test_images/test_998.jpg
#   inflating: test_images/test_999.jpg

# %%
# ディレクトリ内のデータの確認
# %ls
# Out:
# label_master.tsv  sample_submit.tsv  test_images.zip   train_master.tsv
# sample_data/      test_images/       train_images.zip

# %% [markdown]
# # 事前準備

# %%
# ライブラリのインポート
import os
import random
from glob import glob
from warnings import filterwarnings

import argparse

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import cv2
from PIL import Image

import torch
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
from torchsummary import summary

from collections import defaultdict

filterwarnings('ignore')  # warningをオフにする

# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
# 初期設定
from google.colab import drive
drive.mount('/content/gdrive') # マウント先

ATTACH_PATH = '/content/gdrive/MyDrive/CIFAR10-Pytorch'  # 保存先のベースディレクトリ  
SAVE_MODEL_PATH = f'{ATTACH_PATH}/model/'  # モデルの保存先

# 提出データの保存先
SUBMIT_PATH = f'{ATTACH_PATH}/submit/'

# 提出データの名前
submit_name = 'sample_submission.tsv'

# 画像データのディレクトリ
img_dir = 'test_images/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# デバイスの設定
device = 'cuda' if torch.cuda.is_available() else 'cpu'
kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {} # GPUが使える場合、DataLoaderでのミニバッチの取り出しを高速化
print(f'デバイス：{device}')
# Out:
# デバイス：cuda

# %%
# ハイパーパラメータの設定
parser = argparse.ArgumentParser()
parser.add_argument('--image_size', type=int, default=96)
parser.add_argument('--num_classes', type=int, default=10)
opt = parser.parse_args(args=[])
print(opt)
# Out:
# Namespace(image_size=96, num_classes=10)

# %% [markdown]
# # 学習済みパラメータの読み込み

# %%
# モデルのパス
model_path = f'{SAVE_MODEL_PATH}mobilenet_v3_large_finetuning.pth'

# %%
model = models.mobilenet_v3_large()
fc_in_features = model.classifier[0].out_features # 最終レイヤー関数の次元数
model.classifier[3] = nn.Linear(fc_in_features, opt.num_classes) # 最終レイヤー関数の付け替え
print(model)
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=1280, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1280, out_features=10, bias=True)
#   )
# )

# %%
model.load_state_dict(torch.load(model_path)) # 学習済みモデルの読み込み
# Out:
# <All keys matched successfully>

# %%
# モデルをGPUに送る
model.to(device)
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=1280, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1280, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # Dataset, Dataloader

# %%
# データの読み込み
test = pd.read_csv('sample_submit.tsv', header=None, sep='\t')
print(test.head())
print('データ数: ', test.shape[0])
# Out:
#             0  1
# 0  test_0.jpg  3
# 1  test_1.jpg  8
# 2  test_2.jpg  3
# 3  test_3.jpg  3
# 4  test_4.jpg  2
# データ数:  8000

# %%
# 画像データの名前リストの抽出
x_test = test[0].values
dummy = test[0].values
print(x_test, f'データ数：{len(x_test)}')
# Out:
# ['test_0.jpg' 'test_1.jpg' 'test_2.jpg' ... 'test_7997.jpg'
#  'test_7998.jpg' 'test_7999.jpg'] データ数：8000

# %%
# transformの設定
transform = {
    'train': transforms.Compose([
        transforms.Resize(opt.image_size),
        transforms.RandomHorizontalFlip(p=0.2),
        transforms.RandomRotation(degrees=20),
        transforms.RandomAffine(degrees=[-10, 10], translate=(0.1, 0.1), scale=(0.5, 1.5)),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
    'val': transforms.Compose([
        transforms.Resize(opt.image_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
}

# %% [markdown]
# # Dataset

# %%
# Datasetの設定
class CifarDataset(Dataset):
    def __init__(self, image_name_list, label_list, img_dir, transform=None, phase=None):
        self.image_name_list = image_name_list # 画像ファイル名
        self.label_list = label_list # ラベル
        self.img_dir = img_dir # 画像データのディレクトリ
        self.phase = phase # 変数phaseで学習(train)もしくは検証(val)の設定を行う
        self.transform = transform

    def __len__(self):
        return len(self.image_name_list) # 1エポックあたりに読み込むデータ数として、入力データの数を指定

    def __getitem__(self, index):
        
        # index番目の画像を読み込み、前処理を行う
        image_path = os.path.join(self.img_dir, self.image_name_list[index]) # train_master.iloc[index, 0]はファイル名を抽出
        img = Image.open(image_path)
        img = self.transform[self.phase](img)
        
        # index番目のラベルを取得する
        label = self.label_list[index]
        
        return img, label

# %%
# Datasetのインスタンス作成
test_dataset = CifarDataset(x_test, dummy, img_dir, transform=transform, phase='val')

# %% [markdown]
# # DataLoader

# %%
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# # テストデータの予測

# %%
# 予測データフレームの作成
preds = []

# dataloaderから、ミニバッチ単位でデータを読み込む
for images, _ in test_dataloader:
    
    # 入力データをdeviceへ
    images = images.to(device)
    
    # 学習済みモデルを推論モードに設定
    model.eval()
    
    # モデルによる変換
    outputs = model(images)
    pred = torch.argmax(outputs, dim=1)
    pred = pred.to('cpu').numpy()

    # 予測値をリストに追加
    preds.extend(pred)

# %% [markdown]
# # 提出

# %%
# 提出用データの読み込み
sub = pd.read_csv('sample_submit.tsv', header=None, sep='\t')
print(sub.head())
print('データ数: ', sub.shape[0])
# Out:
#             0  1
# 0  test_0.jpg  3
# 1  test_1.jpg  8
# 2  test_2.jpg  3
# 3  test_3.jpg  3
# 4  test_4.jpg  2
# データ数:  8000

# %%
# 目的変数カラムの置き換え
sub[1] = preds
print(sub.head())
# Out:
#             0  1
# 0  test_0.jpg  6
# 1  test_1.jpg  1
# 2  test_2.jpg  5
# 3  test_3.jpg  9
# 4  test_4.jpg  3

# %%
# ファイルのエクスポート
sub.to_csv(SUBMIT_PATH+submit_name, sep='\t', header=None, index=None)
